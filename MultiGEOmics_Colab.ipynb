# %% [markdown]
# <a href="https://colab.research.google.com/github/ayyucedemirbas/MultiGEOmics_Colab/blob/main/MultiGEOmics_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/bozdaglab/MultiGEOmics.git
# !pip uninstall dgl dglgo torch torchvision torchaudio torchdata numpy -y
# !pip install "numpy<2.0" "dill"
# !pip install torch==2.2.1 torchvision==0.17.1 torchaudio==2.2.1 --index-url https://download.pytorch.org/whl/cu121
# !pip install torchdata==0.7.1

# !pip install dgl -f https://data.dgl.ai/wheels/cu121/repo.html

# !grep -v "torch" MultiGEOmics/req.txt | grep -v "dgl" | grep -v "numpy" > clean_req.txt
# !pip install -r clean_req.txt

# %%
# !find MultiGEOmics/src -name "*.py" -exec sed -i "s/from dgl.heterograph import DGLHeteroGraph/from dgl import DGLGraph as DGLHeteroGraph/g" {} +

# %%
import torch
import dgl
import torchdata

print(f"PyTorch: {torch.__version__}")
print(f"DGL: {dgl.__version__}")
print(f"CUDA: {torch.cuda.is_available()}")
# Out:
# PyTorch: 2.2.1+cu121
# DGL: 2.1.0+cu121
# CUDA: True

# %%
# !pip install torch_geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.8 MB/s eta 0:00:00
# ...

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:128"

# %%
# !python MultiGEOmics/src/main_run.py --dataset=TCGA_GBM --epochs=450 --early_stopping=150
# Out:
#   0% 0/450 [00:00<?, ?it/s]INFO:train_eval:Train loss:223.1622, Train accuracy:0.3183, f1_macro:0.1317, f1_weighted:0.4730, matthews_corrcoef_:0.0251
# INFO:train_eval:Val accuracy:0.2692, f1_macro:0.1061, f1_weighted:0.4242, matthews_corrcoef_:0.0000
#   0% 1/450 [00:01<09:35,  1.28s/it]INFO:train_eval:Train loss:104.4275, Train accuracy:0.2637, f1_macro:0.1043, f1_weighted:0.4173, matthews_corrcoef_:0.0000
# INFO:train_eval:Val accuracy:0.2308, f1_macro:0.0938, f1_weighted:0.3750, matthews_corrcoef_:0.0000
#   0% 2/450 [00:01<06:45,  1.11it/s]INFO:train_eval:Train loss:77.8355, Train accuracy:0.2315, f1_macro:0.0940, f1_weighted:0.3760, matthews_corrcoef_:0.0000
# INFO:train_eval:Val accuracy:0.1731, f1_macro:0.0847, f1_weighted:0.2768, matthews_corrcoef_:-0.0663
#   1% 3/450 [00:02<05:48,  1.28it/s]INFO:train_eval:Train loss:31.7474, Train accuracy:0.2122, f1_macro:0.1173, f1_weighted:0.3174, matthews_corrcoef_:0.0708
# ...

# %%
# !CUDA_VISIBLE_DEVICES="" python MultiGEOmics/src/main_run.py --dataset=TCGA_GBM --epochs=450 --early_stopping=150
# Out:
#   0% 0/450 [00:00<?, ?it/s]INFO:train_eval:Train loss:42.0128, Train accuracy:0.2315, f1_macro:0.0940, f1_weighted:0.3760, matthews_corrcoef_:0.0000
# INFO:train_eval:Val accuracy:0.2115, f1_macro:0.1173, f1_weighted:0.3167, matthews_corrcoef_:-0.0097
#   0% 1/450 [00:33<4:12:59, 33.81s/it]^C
